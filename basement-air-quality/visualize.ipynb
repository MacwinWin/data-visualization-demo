# %%
from pyecharts.globals import ThemeType
from pyecharts import options as opts
from pyecharts.charts import Line
import pandas as pd

# %%
df = pd.read_excel('data.xlsx')

# %%
xaxis = df['Time'].to_list()

# %%
line = Line(init_opts=opts.InitOpts(
    width='1920px',
    height='1080px',
    theme=ThemeType.DARK))

# %%
line.add_xaxis(xaxis_data=xaxis)

# %%
for yaxis in ['tVOC(mg/m³)', 'PM2.5(μg/m³)', 'CO2(ppm)', 'Temp(°C)', 'Humi(%)']:
    line.add_yaxis(yaxis, df[yaxis].to_list())

# %% [markdown]
# # 设置缩放

# %%
line.set_global_opts(
    title_opts=opts.TitleOpts(title=""),
    datazoom_opts=opts.DataZoomOpts(),
)

# %% [markdown]
# # 隐藏数值标签

# %%
line.set_series_opts(label_opts=opts.LabelOpts(is_show=False))

# %% [markdown]
# # 在jupyter lab上显示

# %%
from pyecharts.globals import CurrentConfig, NotebookType  
CurrentConfig.NOTEBOOK_TYPE = NotebookType.JUPYTER_LAB
line.load_javascript()
line.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="496d8f7f1ca748abaab2d535c613bd84" class="chart-container" style="width:1920px; height:1080px;"></div>
#     <script>
#         var chart_496d8f7f1ca748abaab2d535c613bd84 = echarts.init(
#             document.getElementById('496d8f7f1ca748abaab2d535c613bd84'), 'dark', {renderer: 'canvas'});
#         var option_496d8f7f1ca748abaab2d535c613bd84 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "line",
#             "name": "tVOC(mg/m\u00b3)",
#             "connectNulls": false,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "data": [
#                 [
#                     "2021/09/04 12:30",
#                     0.192
#                 ],
#                 [
#                     "2021/09/04 12:45",
#                     0.027
#                 ],
#                 [
#                     "2021/09/04 13:00",
#                     0.11
#                 ],
#                 [
#                     "2021/09/04 13:15",
#                     0.046
#                 ],
#                 [
#                     "2021/09/04 13:30",
#                     0.283
#                 ],
#                 [
#                     "2021/09/04 13:45",
#                     0.005
#                 ],
#                 [
#                     "2021/09/04 14:00",
#                     0.178
#                 ],
#                 [
#                     "2021/09/04 14:15",
#                     0.041
#                 ],
#                 [
#                     "2021/09/04 14:30",
#                     0.027
#                 ],
#                 [
#                     "2021/09/04 14:45",
#                     0.009
#                 ],
#                 [
#                     "2021/09/04 15:00",
#                     0.027
#                 ],
#                 [
#                     "2021/09/04 15:15",
#                     0.005
#                 ],
#                 [
#                     "2021/09/04 15:30",
#                     0.009
#                 ],
#                 [
#                     "2021/09/04 15:45",
#                     0.014
#                 ],
#                 [
#                     "2021/09/04 16:00",
#                     0.027
#                 ],
#                 [
#                     "2021/09/04 16:15",
#                     0.005
#                 ],
#                 [
#                     "2021/09/04 16:30",
#                     0.064
#                 ],
#                 [
#                     "2021/09/04 16:45",
#                     0.046
#                 ],
#                 [
#                     "2021/09/04 17:00",
#                     0.037
#                 ],
#                 [
#                     "2021/09/04 17:15",
#                     0.037
#                 ],
#                 [
#                     "2021/09/04 17:30",
#                     0.018
#                 ],
#                 [
#                     "2021/09/04 17:45",
#                     0.069
#                 ],
#                 [
#                     "2021/09/04 18:00",
#                     0.027
#                 ],
#                 [
#                     "2021/09/04 18:15",
#                     0.064
#                 ],
#                 [
#                     "2021/09/04 18:30",
#                     0.055
#                 ],
#                 [
#                     "2021/09/04 18:45",
#                     0.05
#                 ],
#                 [
#                     "2021/09/04 19:00",
#                     0.055
#                 ],
#                 [
#                     "2021/09/04 19:15",
#                     0.027
#                 ],
#                 [
#                     "2021/09/04 19:30",
#                     0.05
#                 ],
#                 [
#                     "2021/09/04 19:45",
#                     0.046
#                 ],
#                 [
#                     "2021/09/04 20:00",
#                     0.046
#                 ],
#                 [
#                     "2021/09/04 20:15",
#                     0.027
#                 ],
#                 [
#                     "2021/09/04 20:30",
#                     0.032
#                 ],
#                 [
#                     "2021/09/04 20:45",
#                     0.027
#                 ],
#                 [
#                     "2021/09/04 21:00",
#                     0.018
#                 ],
#                 [
#                     "2021/09/04 21:15",
#                     0.041
#                 ],
#                 [
#                     "2021/09/04 21:30",
#                     0.018
#                 ],
#                 [
#                     "2021/09/04 21:45",
#                     0.037
#                 ],
#                 [
#                     "2021/09/04 22:00",
#                     0.032
#                 ],
#                 [
#                     "2021/09/04 22:15",
#                     0.018
#                 ],
#                 [
#                     "2021/09/04 22:30",
#                     0.037
#                 ],
#                 [
#                     "2021/09/04 22:45",
#                     0.046
#                 ],
#                 [
#                     "2021/09/04 23:00",
#                     0.037
#                 ],
#                 [
#                     "2021/09/04 23:15",
#                     0.046
#                 ],
#                 [
#                     "2021/09/04 23:30",
#                     0.027
#                 ],
#                 [
#                     "2021/09/04 23:45",
#                     0.064
#                 ],
#                 [
#                     "2021/09/05 00:00",
#                     0.05
#                 ],
#                 [
#                     "2021/09/05 00:15",
#                     0.082
#                 ],
#                 [
#                     "2021/09/05 00:30",
#                     0.091
#                 ],
#                 [
#                     "2021/09/05 00:45",
#                     0.096
#                 ],
#                 [
#                     "2021/09/05 01:00",
#                     0.114
#                 ],
#                 [
#                     "2021/09/05 01:15",
#                     0.101
#                 ],
#                 [
#                     "2021/09/05 01:30",
#                     0.119
#                 ],
#                 [
#                     "2021/09/05 01:45",
#                     0.091
#                 ],
#                 [
#                     "2021/09/05 02:00",
#                     0.101
#                 ],
#                 [
#                     "2021/09/05 02:15",
#                     0.082
#                 ],
#                 [
#                     "2021/09/05 02:30",
#                     0.078
#                 ],
#                 [
#                     "2021/09/05 02:45",
#                     0.05
#                 ],
#                 [
#                     "2021/09/05 03:00",
#                     0.041
#                 ],
#                 [
#                     "2021/09/05 03:15",
#                     0.046
#                 ],
#                 [
#                     "2021/09/05 03:30",
#                     0.027
#                 ],
#                 [
#                     "2021/09/05 03:45",
#                     0.009
#                 ],
#                 [
#                     "2021/09/05 04:00",
#                     0.032
#                 ],
#                 [
#                     "2021/09/05 04:15",
#                     0.032
#                 ],
#                 [
#                     "2021/09/05 04:30",
#                     0.037
#                 ],
#                 [
#                     "2021/09/05 04:45",
#                     0.037
#                 ],
#                 [
#                     "2021/09/05 05:00",
#                     0.027
#                 ],
#                 [
#                     "2021/09/05 05:15",
#                     0.032
#                 ],
#                 [

# %% [markdown]
# # 导出html文件

# %%
line.render()
# Out:
# '/Users/microfat/Git/data-visualization-demo/basement-air-quality/render.html'
